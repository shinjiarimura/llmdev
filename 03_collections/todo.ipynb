# %%
filename = "todo_list.txt"

try:
    with open("todo_list.txt", mode="r", encoding="utf-8") as file:
        todo_list = [line.strip() for line in file]
except FileNotFoundError:
    # ファイルが無い場合は新規作成
    todo_list = []


print("【TODOリスト】")

while True:
    print("番号を入力してください[1:追加、2:表示、3:削除、4:保存と終了]:", end="", flush=True)
    choice = input("")
    
    if choice == "1":
        print("1:追加", flush=True)
        add_todo = input("追加するTODO: ")
        print("追加するTODO: ", add_todo, flush=True)
        todo_list.append(add_todo)
    elif choice == "2":
        print("2:表示", flush=True)
        for i, todo in enumerate(todo_list):
            print(f"{i}. {todo}")
    elif choice == "3":
        print("3:削除", flush=True)

        # todo_list のインデックス番号と要素を表示する。
        for i, todo in enumerate(todo_list):
            print(f"{i}. {todo}")
        
        print("削除する番号: ", flush=True)
        del_todo_num = input("")

        # todo_list から、指定されたインデックス番号の要素を削除する
        try:
            todo_list.pop(int(del_todo_num))
        except:
            # エラーが発生した場合は 無効な番号です。 と表示する
            print("無効な番号です。")
            continue

    elif choice == "4":
        print("4:保存と終了", flush=True)
        try:
            with open(filename, "w", encoding="utf-8") as file:
                file.writelines(f"{todo}\n" for todo in todo_list)
            print("TODOリストを保存して終了します。", flush=True)
            break
        except:
            print("ファイル保存時にエラー発生")
    else:
        print("1-4の数字を入力してください。", flush=True)
# Out:
# 【TODOリスト】
# 番号を入力してください[1:追加、2:表示、3:削除、4:保存と終了]:2:表示
# 0. テストTODO１
# 1. テストTODO３
# 2. テストTODO dog
# 3. テストTODO cat
# 4. dddddd
# 番号を入力してください[1:追加、2:表示、3:削除、4:保存と終了]:3:削除
# 0. テストTODO１
# 1. テストTODO３
# 2. テストTODO dog
# 3. テストTODO cat
# 4. dddddd
# 削除する番号:
# 番号を入力してください[1:追加、2:表示、3:削除、4:保存と終了]:2:表示
# 0. テストTODO３
# 1. テストTODO dog
# 2. テストTODO cat
# 3. dddddd
# 番号を入力してください[1:追加、2:表示、3:削除、4:保存と終了]:4:保存と終了
# TODOリストを保存して終了します。
