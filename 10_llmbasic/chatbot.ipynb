# %%
import os
from dotenv import load_dotenv
from openai import OpenAI
from pprint import pprint

load_dotenv("../.env")

client = OpenAI(api_key=os.environ['API_KEY'])

MODEL_NAME = "gpt-4o-mini"

# %%
messages = []

while(True):
    # 質問受付
    message = input("メッセージを入力：")

    # 質問が入力されない場合終了
    if message.strip() == "":
        break
    print(f"質問:{message}")

    messages.append({"role": "user", "content": message.strip()})

    # やり取りが8を超えたら古いメッセージから削除
    if len(messages) > 8:
        del_message = messages.pop(0)

    stream = client.chat.completions.create(
        model=MODEL_NAME,
        messages=messages,
        stream=True,
    )

    # 回答を表示
    response_message = ""
    for chunk in stream:
        if chunk.choices:
            next = chunk.choices[0].delta.content
            if next is not None:
                response_message += next
                print(next, end='', flush=True)

    messages.append({"role": "assistant", "content": response_message})

print("\n---ご利用ありがとうございました！---")
# Out:
# 質問:卵焼きの作り方を教えて。
# 卵焼きの作り方を説明します。日本の卵焼き（だし巻き卵）の基本的なレシピをご紹介します。
#
# ### 材料
# - 卵 4個
# - だし汁 100ml（好みに応じて、だしの素を使っても可）
# - 砂糖 大さじ1
# - 醤油 小さじ1
# - 塩 少々
# - サラダ油（焼くとき用）
#
# ### 作り方
# 1. **卵液を作る**: ボウルに卵を割り入れ、だし汁、砂糖、醤油、塩を加えます。泡立て器やフォークでよく混ぜ合わせ、滑らかな卵液を作ります。
#
# 2. **フライパンを温める**: 中火でフライパンを温め、サラダ油を薄く引きます。油が温まったら、余分な油は拭き取ります。
#
# 3. **卵を焼く**: 最初の卵液をフライパンに流し込み、全体に広げます。表面が少し固まり始めたら、手前から奥方向に卵焼きを巻いていきます。
#
# 4. **巻き続ける**: 巻いた卵をフライパンの端に寄せ、新しい卵液を流し込みます。さらに巻いた卵の上に卵液が流れ込むようにします。この作業を繰り返して、卵焼きを作り続けます。
#
# 5. **形を整える**: 卵焼きが焼き上がったら、フライパンから取り出し、少し冷ましてから包丁で切り分けます。お好みで、海苔や細ねぎをトッピングしても美味しいです。
#
# 6. **完成**: お皿に盛り付けて、お好みの味付け（醤油やみりんなど）で召し上がれ。
#
# ### ポイント
# - 焼くときの火加減は中火から弱火に調整し、焦がさないように注意してください。
# - だしはお好みで調整できます。具材をのせる場合は、他の材料を混ぜてアレンジしても良いでしょう。
#
# お好みで味付けや形を変えて、自分だけの卵焼きを楽しんでください！質問:甘めの味付けにしたい。
# 甘めの卵焼きを作りたい場合、砂糖の量を増やすことで実現できます。以下は、甘めの卵焼きのレシピです。
#
# ### 材料
# - 卵 4個
# - だし汁 100ml（だしの素を使うことも可）
# - 砂糖 大さじ2（お好みに応じて調整）
# - 醤油 小さじ1（ほとんどのレシピに入っていますが、甘みを強くしたい場合は省いても可）
# - 塩 少々
# - サラダ油（焼くとき用）
#
# ### 作り方
# 1. **卵液を作る**: ボウルに卵を割り入れ、だし汁、砂糖、醤油、塩を加えます。泡立て器やフォークでしっかりと混ぜ合わせ、滑らかな卵液を作ります。甘さが強い卵焼きが好きな場合は、砂糖をさらに追加しても良いでしょう。
#
# 2. **フライパンを温める**: 中火でフライパンを温め、サラダ油を薄く引きます。油が温まったら、余分な油は拭き取ります。
#
# 3. **卵を焼く**: 最初の卵液をフライパンに流し込み、全体に広げます。表面が少し固まり始めたら、手前から奥方向に卵焼きを巻いていきます。
#
# 4. **巻き続ける**: 巻いた卵をフライパンの端に寄せ、新しい卵液を流し込みます。さらに、巻いた卵の上に卵液が流れ込むように作業を繰り返します。
#
# 5. **形を整える**: 卵焼きが焼き上がったら、フライパンから取り出し、少し冷ました後に包丁で切り分けます。
#
# 6. **完成**: お皿に盛り付けて、甘さが引き立つようにしてお召し上がりください。
#
# ### おすすめのアレンジ
# - さらに甘さを加えたいときは、メープルシロップや蜂蜜を少し加えてみるのも良いでしょう。
# - 餡やフルーツとの組み合わせで、甘さを楽しむ食べ方もおすすめです。
#
# 甘い卵焼きを楽しんでください！
# ---ご利用ありがとうございました！---
